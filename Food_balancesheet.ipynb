# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import Series, DataFrame

# %matplotlib inline

# %%
foodbalancesheet= pd.read_csv('/Users/temidayo/downloads/hamoye/FoodBalanceSheets_E_Africa_NOFLAG.csv', index_col=0)

# %%
print(foodbalancesheet.shape)
foodbalancesheet.head()
# Out:
# (60943, 11)
#               Area  Item Code         Item  Element Code  \
# Area Code
# 4          Algeria       2501   Population           511
# 4          Algeria       2501   Population          5301
# 4          Algeria       2901  Grand Total           664
# 4          Algeria       2901  Grand Total           674
# 4          Algeria       2901  Grand Total           684
#
#                                           Element             Unit     Y2014  \
# Area Code
# 4                   Total Population - Both sexes     1000 persons  38924.00
# 4                        Domestic supply quantity      1000 tonnes      0.00
# 4                   Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 4          Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4              Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#               Y2015     Y2016     Y2017     Y2018
# Area Code
# 4          39728.00  40551.00  41389.00  42228.00
# ...

# %%
foodbalancesheet.describe()
# Out:
#           Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000   59354.000000   59395.000000
# mean    2687.176706   3814.856456     134.196282     135.235966
# std      146.055739   2212.007033    1567.663696    1603.403984
# min     2501.000000    511.000000   -1796.000000   -3161.000000
# 25%     2562.000000    684.000000       0.000000       0.000000
# 50%     2630.000000   5142.000000       0.090000       0.080000
# 75%     2775.000000   5511.000000       8.340000       8.460000
# max     2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.080000       0.100000       0.070000
# ...

# %%
category_sum= DataFrame(foodbalancesheet.groupby(['Item'])['Y2014','Y2015', 'Y2016', 'Y2017', 'Y2018'].sum())
print(category_sum)
# Out:
#                          Y2014      Y2015      Y2016      Y2017      Y2018
# Item
# Alcohol, Non-Food      2403.00    2180.00    2223.00    2348.00    2293.00
# Alcoholic Beverages  102410.11   98783.72   96958.75   95581.06   97847.27
# Animal Products       11935.65   11811.73   11661.69   11547.65   11578.61
# Animal fats          209460.54  200675.72  183314.22  269617.53  269648.27
# Apples and products    9499.23   10559.15    9853.26   10198.90    9640.51
# ...                        ...        ...        ...        ...        ...
# Vegetables, Other    155038.96  158104.08  156218.90  157752.59  163987.21
# Vegetal Products     107145.19  107064.17  106792.72  107655.20  107775.39
# Wheat and products   232670.13  234710.51  239377.07  240047.62  242645.19
# Wine                   4497.36    4251.81    3872.09    4178.02    4039.32
# Yams                 200396.96  203151.78  220626.20  229174.59  221272.09
#
# [119 rows x 5 columns]
# ...

# %%
element_sum= DataFrame(foodbalancesheet.groupby(['Element'])['Y2014','Y2015', 'Y2016', 'Y2017', 'Y2018'].sum())
print(element_sum)
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
foodbalancesheet.isnull().sum()
# Out:
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# % of missing value
foodbalancesheet.isnull().sum()/foodbalancesheet.shape[0]*100
# Out:
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y2014           2.607354
# Y2015           2.540078
# Y2016           2.518747
# Y2017           2.471162
# Y2018           2.356300
# dtype: float64

# %%
foodbalancesheet.corr()
# Out:
#               Item Code  Element Code     Y2014     Y2015     Y2016     Y2017  \
# Item Code      1.000000     -0.024683  0.021722  0.020857  0.020109  0.021494
# Element Code  -0.024683      1.000000  0.024457  0.023889  0.023444  0.024254
# Y2014          0.021722      0.024457  1.000000  0.994647  0.996081  0.995230
# Y2015          0.020857      0.023889  0.994647  1.000000  0.995739  0.988048
# Y2016          0.020109      0.023444  0.996081  0.995739  1.000000  0.992785
# Y2017          0.021494      0.024254  0.995230  0.988048  0.992785  1.000000
# Y2018          0.021314      0.024279  0.994872  0.988208  0.992757  0.998103
#
#                  Y2018
# Item Code     0.021314
# Element Code  0.024279
# Y2014         0.994872
# Y2015         0.988208
# Y2016         0.992757
# Y2017         0.998103
# Y2018         1.000000

# %%
element_sum= DataFrame(foodbalancesheet.groupby(['Element'])['Y2014','Y2015', 'Y2016', 'Y2017', 'Y2018'].sum())
print(element_sum)
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
import_quantity = foodbalancesheet.pivot_table(['Y2018'], index='Area', columns='Element', aggfunc=sum)
import_quantity.head()
# Out:
#                                 Y2018                  \
# Element      Domestic supply quantity Export Quantity
# Area
# Algeria                      90023.42          811.54
# Angola                       59590.22         7962.28
# Benin                        31447.90          729.44
# Botswana                      3045.85          101.68
# Burkina Faso                 25705.16         1088.16
#
#                                                                      \
# Element      Fat supply quantity (g/capita/day)      Feed      Food
# Area
# Algeria                                  309.09  10668.00  63736.33
# Angola                                   230.90   7859.66  37256.56
# Benin                                    207.82   4662.54  16209.34
# Botswana                                 261.12     28.04   2378.80
# Burkina Faso                             264.29   1031.50  20525.63
#
#                                             \
# Element      Food supply (kcal/capita/day)
# ...

# %%
import_quantity.loc[['Algeria']]
# Out:
#                            Y2018                  \
# Element Domestic supply quantity Export Quantity
# Area
# Algeria                 90023.42          811.54
#
#                                                                \
# Element Fat supply quantity (g/capita/day)     Feed      Food
# Area
# Algeria                             309.09  10668.0  63736.33
#
#                                                                            \
# Element Food supply (kcal/capita/day) Food supply quantity (kg/capita/yr)
# Area
# Algeria                       13288.0                             1509.28
#
#                                                                              \
# Element Import Quantity  Losses Other uses (non-food) Processing Production
# Area
# Algeria        36238.29  7708.0               3970.08     2479.0   60766.67
#
#                                                                  \
# Element Protein supply quantity (g/capita/day) Residuals   Seed
# Area
# ...

# %%
A=foodbalancesheet.Area.value_counts()
print('Number of Unique Country :', len(A))
# Out:
# Number of Unique Country : 49
